# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("CardioGoodFitness-1.csv")

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
sns.relplot(x="Age", y="Miles", data = df)

# %%
sns.relplot(x="Age", y="Miles", hue = "Gender", data = df)

# %%
sns.relplot(x="Age", y="Miles", hue = "Income", data = df);

# %%
sns.relplot(x="Age", y="Miles", size = "Income", data = df);

# %% [markdown]
# Jiter plot

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
sns.catplot(x="Age", y="Gender", data=df)

# %%
sns.catplot(x="Age", y="Gender",jitter=False, data=df)

# %%
sns.catplot(x="Age", y="Gender",hue="MaritalStatus", data=df)

# %%
sns.catplot(x="Age", y="Gender",kind="swarm", data=df)

# %%
sns.catplot(x="Age", y="Gender",hue="MaritalStatus",kind="swarm", data=df)

# %%
sns.catplot(x="Age", y="Gender",kind="box", data=df)

# %%
sns.catplot(x="Age", y="Gender",hue="MaritalStatus",kind="box", data=df)

# %%
sns.catplot(x="Age", y="Gender",hue="MaritalStatus",kind="violin", data=df)

# %%
sns.catplot(x="Age", y="Gender",hue="MaritalStatus",kind="violin",split=True, data=df)

# %%
sns.catplot(x="Age", y="Gender",hue="MaritalStatus",kind="bar", data=df)

# %%
sns.catplot(x="Age", y="Gender",hue="MaritalStatus",kind="point", data=df)

# %%
sns.catplot(x="Gender", y="Age",hue="Product",col='MaritalStatus',aspect=.9,kind="swarm",data=df)

# %%
sns.distplot(df.Income)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Income', ylabel='Density'>

# %%
sns.distplot(df.Income,kde=False,rug=True)
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Income'>

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x="Gender", y="Age", data=df, kind="boxen",height=4, aspect=2.7, hue = "Product")
